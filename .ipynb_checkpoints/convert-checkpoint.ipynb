# %%
import pandas as pd 
from sqlalchemy import text,create_engine

# %%
engin=create_engine('sqlite:///us_cunses_data.db')

# %%
df=pd.read_csv('US_Census_Data.csv')

# %%
df.to_sql('Census_Data',engin,index=False,if_exists='replace')
# Out:
# 85

# %%
Census_Data=pd.read_sql(text('select * from Census_Data'),con=engin.connect())

# %%
Census_Data.head()
# Out:
#                                                 Fact Fact Note    Alabama  \
# 0       Population estimates, July 1, 2016,  (V2016)      None  4,863,300
# 1  Population estimates base, April 1, 2010,  (V2...      None  4,780,131
# 2  Population, percent change - April 1, 2010 (es...      None      1.70%
# 3                  Population, Census, April 1, 2010      None  4,779,736
# 4  Persons under 5 years, percent, July 1, 2016, ...      None      6.00%
#
#     Alaska    Arizona   Arkansas  California   Colorado Connecticut Delaware  \
# 0  741,894  6,931,071  2,988,248  39,250,017  5,540,545   3,576,452  952,065
# 1  710,249  6,392,301  2,916,025  37,254,522  5,029,324   3,574,114  897,936
# 2    4.50%      8.40%      2.50%       5.40%     10.20%       0.10%    6.00%
# 3  710,231  6,392,017  2,915,918  37,253,956  5,029,196   3,574,097  897,934
# 4    7.30%      6.30%      6.40%       6.30%      6.10%       5.20%    5.80%
#
# ...
